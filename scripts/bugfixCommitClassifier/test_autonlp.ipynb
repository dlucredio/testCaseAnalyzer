# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from autoviml.Auto_NLP import Auto_NLP

data=pd.read_csv('train.csv')

train,test = train_test_split(data, test_size=0.2)

input_feature, target = "SentimentText", "Sentiment"

train["Sentiment"] = pd.to_numeric(train["Sentiment"])
test["Sentiment"] = pd.to_numeric(test["Sentiment"])

train_x, test_x, final, predicted=Auto_NLP(input_feature,train,test,target,score_type="balanced_accuracy",modeltype="classification",verbose=0,build_model=True)
# Out:
# Imported Auto_ViML version: 0.1.710. Call using:
#              m, feats, trainm, testm = Auto_ViML(train, target, test,
#                             sample_submission='',
#                             scoring_parameter='', KMeans_Featurizer=False,
#                             hyper_param='RS',feature_reduction=True,
#                              Boosting_Flag='CatBoost', Binning_Flag=False,
#                             Add_Poly=0, Stacking_Flag=False,Imbalanced_Flag=False,
#                             verbose=1)
#
#
# Imported Auto_NLP version: 0.1.01.. Call using:
#      train_nlp, test_nlp, nlp_pipeline, predictions = Auto_NLP(
#                 nlp_column, train, test, target, score_type='balanced_accuracy',
#                 modeltype='Classification',top_num_features=200, verbose=0,
#                 build_model=True)
# <style>.container { width:95% !important; }</style>
# [nltk_data] Downloading collection 'popular'
# [nltk_data]    |
# [nltk_data]    | Downloading package cmudict to
# [nltk_data]    |     /home/daniel/nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package gazetteers to
# [nltk_data]    |     /home/daniel/nltk_data...
# [nltk_data]    |   Package gazetteers is already up-to-date!
# [nltk_data]    | Downloading package genesis to
# [nltk_data]    |     /home/daniel/nltk_data...
# [nltk_data]    |   Package genesis is already up-to-date!
# [nltk_data]    | Downloading package gutenberg to
# [nltk_data]    |     /home/daniel/nltk_data...
# [nltk_data]    |   Package gutenberg is already up-to-date!
# [nltk_data]    | Downloading package inaugural to
# [nltk_data]    |     /home/daniel/nltk_data...
# [nltk_data]    |   Package inaugural is already up-to-date!
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /home/daniel/nltk_data...
# [nltk_data]    |   Package movie_reviews is already up-to-date!
# [nltk_data]    | Downloading package names to
# [nltk_data]    |     /home/daniel/nltk_data...
# [nltk_data]    |   Package names is already up-to-date!
# [nltk_data]    | Downloading package shakespeare to
# [nltk_data]    |     /home/daniel/nltk_data...
# [nltk_data]    |   Package shakespeare is already up-to-date!
# [nltk_data]    | Downloading package stopwords to
# [nltk_data]    |     /home/daniel/nltk_data...
# [nltk_data]    |   Package stopwords is already up-to-date!
# [nltk_data]    | Downloading package treebank to
# [nltk_data]    |     /home/daniel/nltk_data...
# [nltk_data]    |   Package treebank is already up-to-date!
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     /home/daniel/nltk_data...
# [nltk_data]    |   Package twitter_samples is already up-to-date!
# [nltk_data]    | Downloading package omw to /home/daniel/nltk_data...
# [nltk_data]    |   Package omw is already up-to-date!
# [nltk_data]    | Downloading package omw-1.4 to
# [nltk_data]    |     /home/daniel/nltk_data...
# [nltk_data]    |   Package omw-1.4 is already up-to-date!
# [nltk_data]    | Downloading package wordnet to
# [nltk_data]    |     /home/daniel/nltk_data...
# [nltk_data]    |   Package wordnet is already up-to-date!
# [nltk_data]    | Downloading package wordnet2021 to
# [nltk_data]    |     /home/daniel/nltk_data...
# [nltk_data]    |   Package wordnet2021 is already up-to-date!
# [nltk_data]    | Downloading package wordnet31 to
# [nltk_data]    |     /home/daniel/nltk_data...
# [nltk_data]    |   Package wordnet31 is already up-to-date!
# [nltk_data]    | Downloading package wordnet_ic to
# [nltk_data]    |     /home/daniel/nltk_data...
# [nltk_data]    |   Package wordnet_ic is already up-to-date!
# [nltk_data]    | Downloading package words to
# [nltk_data]    |     /home/daniel/nltk_data...
# [nltk_data]    |   Package words is already up-to-date!
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     /home/daniel/nltk_data...
# [nltk_data]    |   Package maxent_ne_chunker is already up-to-date!
# [nltk_data]    | Downloading package punkt to
# [nltk_data]    |     /home/daniel/nltk_data...
# [nltk_data]    |   Package punkt is already up-to-date!
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     /home/daniel/nltk_data...
# [nltk_data]    |   Package snowball_data is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /home/daniel/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    |
# [nltk_data]  Done downloading collection popular
# Auto NLP processing on NLP Column: SentimentText
# Shape of Train Data: 400 rows
#     Shape of Test Data: 100 rows
#     Added 9 summary columns for counts of words and characters in each row
# Cleaning text in Train data for SentimentText column
#     Faster text processing using clean_tweets function, since top_num_features exceeds 300
# Train data Text cleaning completed. Time taken = 0 seconds
#
# For target = Sentiment
#
#     For class = 0
# Top 200 n-grams
# : []
#     Top n-grams that are most frequent in this class are: 0
#
#     For class = 1
# Top 200 n-grams
# : []
#     Top n-grams that are most frequent in this class are: 0
# Time Taken = 0 seconds
# ##################    THIS IS FOR BUILD_MODEL = TRUE           #################
# Building Model and Pipeline for NLP column = SentimentText. This will take time...
#        Class  -> Counts -> Percent
#            0:     270  ->   67.5%
#            1:     130  ->   32.5%
#     Selected the maximum number of features limit = 398
# Performing RandomizedSearchCV across 30 params. Optimizing for accuracy
#     Using train data = (360,) and Cross Validation data = (40,)
# Using a Calibrated Classifier in this Multi_Classification dataset to improve results...
# Since top_num_features = 300, selecting Random Forest Classifier model. If you need different model, decrease it <300.
# Training completed. Time taken for training = 0.2 minutes
# Best Params of NLP pipeline are: {'selectkbest__k': 301, 'tfidfvectorizer__binary': False, 'tfidfvectorizer__encoding': 'utf-8', 'tfidfvectorizer__max_df': 0.8319480853192148}
# <style>.container { width:95% !important; }</style>
# <style>.container { width:95% !important; }</style>
#   Now transforming Train data to return as output...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 14
#      11 train["Sentiment"] = pd.to_numeric(train["Sentiment"])
#      12 test["Sentiment"] = pd.to_numeric(test["Sentiment"])
# ---> 14 train_x, test_x, final, predicted=Auto_NLP(input_feature,train,test,target,score_type="balanced_accuracy",modeltype="classification",verbose=0,build_model=True)
#
# File ~/.pyenv/versions/3.10.9/envs/testautonlp/lib/python3.10/site-packages/autoviml/Auto_NLP.py:1630, in Auto_NLP(nlp_column, train, test, target, score_type, modeltype, top_num_features, verbose, build_model)
#    1627 print('  Now transforming Train data to return as output...')
#    1629 trainm = transform_pipe.fit_transform(X, y)
# -> 1630 sel_col_names = np.array(best_vect.get_feature_names())[transform_pipe.named_steps[
#    1631                         'selectkbest'].get_support()]
#    1632 trainm = pd.DataFrame(trainm.todense(),index=train_index,columns=sel_col_names)
#    1633 if not isinstance(test, str):
#
# AttributeError: 'TfidfVectorizer' object has no attribute 'get_feature_names'
